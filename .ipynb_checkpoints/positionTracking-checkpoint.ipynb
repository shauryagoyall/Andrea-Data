# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

pos = pd.read_csv('JC274-20220312.whl', sep=" ",
                 header=None,
                 names=["x1","y1","x2","y2","timestamps","valid"])

# %%
pos.head()
# Out:
#      x1    y1    x2    y2  timestamps  valid
# 0    87    86  1023  1023           1      1
# 1  1023  1023  1023  1023         307      0
# 2   126   109  1023  1023         787      1
# 3   126   109  1023  1023        1267      1
# 4   126   109  1023  1023        1747      1

# %%
pos[pos == 1023] = np.nan # replace 1023 (error value) with NaN
print(pos.describe())
# Out:
#                  x1             y1   x2   y2    timestamps          valid
# count  284451.00000  284451.000000  0.0  0.0  4.638220e+05  463822.000000
# mean       96.11107      82.512999  NaN  NaN  1.113151e+08       0.613276
# std        24.40961      26.353360  NaN  NaN  6.426816e+07       0.487000
# min        14.00000       1.000000  NaN  NaN  1.000000e+00       0.000000
# 25%        80.00000      72.000000  NaN  NaN  5.565733e+07       0.000000
# 50%        86.00000      86.000000  NaN  NaN  1.113149e+08       1.000000
# 75%       117.00000      90.000000  NaN  NaN  1.669730e+08       1.000000
# max       157.00000     157.000000  NaN  NaN  2.226305e+08       1.000000

# %%
x1 = pos["x1"]
y1 = pos["y1"]
timestamps = pos["timestamps"]

# %%
fig, ax = plt.subplots(figsize=(8,8))
ax.plot(x1, y1, linewidth=1)
plt.show()

# %%
timestamps.describe()
# Out:
# count    4.638220e+05
# mean     1.113151e+08
# std      6.426816e+07
# min      1.000000e+00
# 25%      5.565733e+07
# 50%      1.113149e+08
# 75%      1.669730e+08
# max      2.226305e+08
# Name: timestamps, dtype: float64

# %%
print(timestamps.min(), timestamps.max())
print(timestamps.count())
# Out:
# 1 222630494
# 463822

# %%
timestart = 0
timeend = 1_500_000
subset = pos.loc[(timestamps > timestart) & (timestamps < timeend)]
x1_subset = subset["x1"]
y1_subset = subset["y1"]
print(subset)
# Out:
#          x1     y1  x2  y2  timestamps  valid
# 0      87.0   86.0 NaN NaN           1      1
# 1       NaN    NaN NaN NaN         307      0
# 2     126.0  109.0 NaN NaN         787      1
# 3     126.0  109.0 NaN NaN        1267      1
# 4     126.0  109.0 NaN NaN        1747      1
# ...     ...    ...  ..  ..         ...    ...
# 3121    NaN    NaN NaN NaN     1497907      0
# 3122    NaN    NaN NaN NaN     1498387      0
# 3123    NaN    NaN NaN NaN     1498867      0
# 3124    NaN    NaN NaN NaN     1499347      0
# 3125  117.0   84.0 NaN NaN     1499827      1
#
# [3126 rows x 6 columns]

# %%
fig, ax = plt.subplots(figsize=(8,8))
ax.plot(x1_subset, y1_subset, linewidth=2)
plt.xlim(0,160)
plt.ylim(0,160)
plt.show()
