# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

accuracy = pd.read_csv('accuracySimpleData.csv')
print(accuracy.JC240[0])
# Out:
# 46.15

# %%
fig = plt.figure(figsize=(22,11))
ax = fig.add_subplot(111)
# ax.plot(accuracy.Day, accuracy.JC240, c='red')
ax.plot(accuracy.Day[0:8], accuracy.JC240[0:8], c='red')
# ax.plot(accuracy.Day, accuracy.JC241, c='orange')
ax.plot(accuracy.Day[0:13], accuracy.JC241[0:13], c='orange')
ax.plot(accuracy.Day, accuracy.JC258, c='green')
# ax.plot(accuracy.Day[0:10], accuracy.JC258[0:10], c='green')
ax.plot(accuracy.Day, accuracy.JC267, c='blue')
ax.plot(accuracy.Day, accuracy.JC274, c='purple', linewidth=4.5)
ax.yaxis.grid()
