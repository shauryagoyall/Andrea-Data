# %%
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib.ticker as mtick
import datetime

##### Color schemes: Data Color Picker from learnui.design, Coolors #####

##### Import the data #####
JC240_data = pd.read_csv('JC240_data.csv')
JC241_data = pd.read_csv('JC241_data.csv')
JC258_data = pd.read_csv('JC258_data.csv')
JC267_data = pd.read_csv('JC267_data.csv')
JC274_data = pd.read_csv('JC274_data.csv')
JC283_data = pd.read_csv('JC283_data.csv')

# %%
##### Calculate accuracy for over all sessions for a given animal #####
def get_accuracy(JCxxx):
    data_JCxxx = str(JCxxx) + "_data" # concatenate strings
    data_JCxxx = globals()[data_JCxxx] # convert string to variable
    bysession_JCxxx = data_JCxxx.groupby("Session_ID")
    sessions = bysession_JCxxx["Session_ID"].unique().to_numpy(dtype=int)
    accuracy = np.zeros(len(sessions))
    for session in range(1, len(sessions)+1):
        accuracy[session-1] = round(bysession_JCxxx.get_group(session)["CorrectBool"].sum() / bysession_JCxxx.get_group(session).count()[0]*100, 0)
    return accuracy, sessions
    
accuracy_JC240, sessions_JC240 = get_accuracy("JC240")
accuracy_JC241, sessions_JC241 = get_accuracy("JC241")
accuracy_JC258, sessions_JC258 = get_accuracy("JC258")
accuracy_JC267, sessions_JC267 = get_accuracy("JC267")
accuracy_JC274, sessions_JC274 = get_accuracy("JC274")
accuracy_JC283, sessions_JC283 = get_accuracy("JC283")

# %%
##### Calculate arm choice by session #####
def get_arm_choice(JCxxx, rewardArms):
    data_JCxxx = str(JCxxx) + "_data" # concatenate strings for variable name
    data_JCxxx = globals()[data_JCxxx] # convert string to variable
    bysession_JCxxx = data_JCxxx.groupby("Session_ID") # filter by session ID and create a groupby object
    sessions = bysession_JCxxx["Session_ID"].unique() # list sessions
    arms = rewardArms # list arms of interest
    num_arms = len(arms) # count arms
    arm_choice = np.zeros((len(sessions), num_arms+1)) # make a vector that will hold arm choice for each session
                                                        # and add another column for other arms
    num_trials = np.zeros(len(sessions))
    for session in range(1, len(sessions)+1): # iterate over sessions, starting at 1 instead of 0
        num_trials[session-1] = bysession_JCxxx.get_group(session).count()[0] # count number of trials per session
        for arm in range(num_arms): # iterate over arms by indexing numpy array
            this_session = bysession_JCxxx.get_group(session)
            choices_bool = this_session["Arm"]==(arms[arm]) # Boolean of whether arm was chosen
            count = len(choices_bool[choices_bool==True])
            arm_choice[session-1][arm] = count
        arm_choice[session-1][-1] = num_trials[session-1] - arm_choice[session-1][0] - arm_choice[session-1][1] - arm_choice[session-1][2]
                                    # for last column subtract arms of interest from total trials
    arm_choice = arm_choice / num_trials[:,None] # express arm choice as a proportion of total trials
    return num_trials, arm_choice

num_trials_JC240, arm_choice_JC240 = get_arm_choice("JC240", np.array([3, 7, 1]))
num_trials_JC241, arm_choice_JC241 = get_arm_choice("JC241", np.array([3, 7, 1]))
num_trials_JC258, arm_choice_JC258 = get_arm_choice("JC258", np.array([3, 7, 1]))
num_trials_JC267, arm_choice_JC267 = get_arm_choice("JC267", np.array([3, 7, 1]))
num_trials_JC274, arm_choice_JC274 = get_arm_choice("JC274", np.array([8, 4, 5]))
num_trials_JC283, arm_choice_JC283 = get_arm_choice("JC283", np.array([8, 5, 0]))

# %%
##### Calculate performance for each arm #####
def get_arm_accuracy(JCxxx):
    data_JCxxx = str(JCxxx) + "_data" # concatenate strings for variable name
    data_JCxxx = globals()[data_JCxxx] # convert string to variable
    bysession_JCxxx = data_JCxxx.groupby("Session_ID") # filter by session ID and create a groupby object
    sessions = bysession_JCxxx["Session_ID"].unique().to_numpy(dtype=int) # list sessions
    byarm_JCxxx = data_JCxxx.groupby["Arm"] # filter by arm this time; create another groupby object
    arms = byarm_JCxxx["Arm"].unique().to_numpy(dtype=int) # list unique arms; arm 0 is an incomplete trial
    accuracy = np.zeros(len(sessions), len(arms)) # formerly this was named "arm_accuracy, and corresponded to the commented out block"
    for session in range(1, len(sessions)+1):
        accuracy[session-1] = round(bysession_JCxxx.get_group(session)["CorrectBool"].sum() / bysession_JCxxx.get_group(session).count()[0]*100, 0)
    return accuracy, sessions

# %%
# This is now unnecessary, because I simply removed the data that was an issue. Must fix later.
# ##### MANUALLY HARD CODING, FIX LATER #####
# # Accuracy is incorrect for day 12 because 3rd flavor was only introduced later
# accuracy_JC241[13] = 63
# print(accuracy_JC241[13])

# Manually deleted forced choice trials
# # Accuracy is incorrect for JC258 due to forced choice trial
# accuracy_JC258[10] = int(30/69*100)
# accuracy_JC258[11] = int(33/69*100)
# accuracy_JC258[12] = int(2/6*100)
# accuracy_JC258[13] = int(19/49*100)

# %%
##### Plot performance and arm choice for two paired associations #####
fig = plt.figure(figsize=(22,11))
plt.tight_layout()

##### Colorscheme: #####
cscheme = ["0.8", "#003f5c", "#769dbc","#b7dcfb"]

##### Line plot format #####
# ### Default ###
# linefmt = 2
# markerfmt = 5
### large ###
linefmt = 3
markerfmt = 6

##### Plot performance #####
ax1 = fig.add_subplot(111)

# ##### JC240 #####
# ax1.plot(sessions_JC240[0:8], accuracy_JC240[0:8], color=cscheme[0], linewidth=linefmt, marker='o', markersize=markerfmt, label='JC240') # 2 flavors

# ##### JC241 #####
# ax1.plot(sessions_JC241[0:13], accuracy_JC241[0:13], color=cscheme[0], linewidth=linefmt, marker='o', markersize=markerfmt, label='JC241') # 2 flavors

##### JC258 #####
ax1.plot(sessions_JC258[0:10], accuracy_JC258[0:10], color='darkgreen', linewidth=linefmt, marker='o', markersize=markerfmt, label='JC258 "Kirillov"') # 2 flavors

# # ##### JC267 #####
# ax1.plot(sessions_JC267[0:10], accuracy_JC267[0:10], color=cscheme[0], linewidth=linefmt, marker='o', markersize=markerfmt, label='JC267') # 2 flavors

##### JC274 #####
ax1.plot(sessions_JC274[0:11], accuracy_JC274[0:11], color=cscheme[1], linewidth=linefmt, marker='o', markersize=markerfmt, label='JC274 "Jones"') # 2 flavors

##### JC283 #####
ax1.plot(sessions_JC283[0:14], accuracy_JC283[0:14], color='maroon', linewidth=linefmt, marker='o', markersize=markerfmt, label='JC283 "Gump"') # 2 flavors

# ##### Formatting #####
# ax1.set_title("Performance for two paired associations", fontsize=26,y=1.03)
# ax1.tick_params(labelsize=15)
# ax1.set_xlabel("Training day", fontsize=15)
# ax1.set_ylabel("Accuracy", fontsize=15)
# # ax1.set_xlim(0.5,8.5) # just to align the two subplot x-axes
# ax1.xaxis.set_major_locator(mtick.MultipleLocator(1))
# ax1.set_ylim(-5,100)
# ax1.yaxis.set_major_formatter(mtick.FormatStrFormatter('%.0f%%'))
# ax1.yaxis.grid()
# # ax1.margins(x=0.05)

##### Formatting large #####
ax1.set_title("Performance for two paired associations", fontsize=50,y=1.03)
ax1.tick_params(labelsize=30)
ax1.set_xlabel("Training day", fontsize=30)
ax1.set_ylabel("Accuracy", fontsize=30)
# ax1.set_xlim(0.5,8.5) # just to align the two subplot x-axes
ax1.xaxis.set_major_locator(mtick.MultipleLocator(1))
ax1.set_xlim(0.5,14.5)
ax1.set_ylim(-5,100)
ax1.yaxis.set_major_formatter(mtick.FormatStrFormatter('%.0f%%'))
ax1.yaxis.grid()
ax1.axhline(y=80, c='black', ls='--', linewidth=3) # color formerly #ae2012
# ax1.margins(x=0.05)

# large legend #
ax1.legend(loc=4, fontsize=30, framealpha=1)

plt.show()
timestamp = datetime.datetime.today().strftime("%Y-%m-%d-%H%M%S")
# plt.savefig("Performance 2 pairs "+timestamp+".png")
# plt.savefig("Performance 2 pairs "+timestamp+".svg")
# plt.savefig("Performance 2 pairs "+timestamp+".jpg")

# %%
##### Plot performance and arm choice day after after 3rd paired association #####
fig = plt.figure(figsize=(22,11))
plt.tight_layout()

cscheme = ["0.8", "#003f5c", "#769dbc","#b7dcfb"]

##### Subplot 1 #####
##### Plot performance #####
ax1 = fig.add_subplot(111)

##### Line plot format #####
# ### Default ###
# linefmt = 2
# markerfmt = 5
### large ###
linefmt = 4 
markerfmt = 10

# ##### JC240 #####
# ax1.plot(sessions_JC240[0:8], accuracy_JC240[0:8], color=cscheme[0], linewidth=linefmt, marker='o', markersize=markerfmt, label='JC240') # 2 flavors
# ax1.plot(sessions_JC240[7:9], accuracy_JC240[7:9], color='0.8', linewidth=linefmt, ls='--', marker='o', markersize=markerfmt) # gray line
# ax1.plot(sessions_JC240[8:9], accuracy_JC240[8:9], color='k', linewidth=linefmt, marker='o', markersize=markerfmt) # only first day after introducing 3rd flavor

# ##### JC241 #####
# ax1.plot(sessions_JC241[0:13], accuracy_JC241[0:13], color=cscheme[0], linewidth=linefmt, marker='o', markersize=markerfmt, label='JC241') # 2 flavors
# ax1.plot(sessions_JC241[12:14], accuracy_JC241[12:14], color='0.8', linewidth=linefmt, ls='--', marker='o', markersize=markerfmt) # gray line
# ax1.plot(sessions_JC241[13:14], accuracy_JC241[13:14], color='k', linewidth=linefmt, marker='o', markersize=markerfmt) # only first day after introducing 3rd flavor

##### JC258 #####
ax1.plot(sessions_JC258[0:10], accuracy_JC258[0:10], color=cscheme[1], linewidth=linefmt, marker='o', markersize=markerfmt, label='JC258') # 2 flavors
ax1.plot(sessions_JC258[9:11], accuracy_JC258[9:11], color='0.8', linewidth=linefmt, ls='--', marker='o', markersize=markerfmt) # gray line
ax1.plot(sessions_JC258[10:11], accuracy_JC258[10:11], color='k', linewidth=linefmt, marker='o', markersize=markerfmt) # only first day after introducing 3rd flavor

##### JC274 #####
ax1.plot(sessions_JC274[0:11], accuracy_JC274[0:11], color=cscheme[3], linewidth=linefmt, marker='o', markersize=markerfmt, label='JC274')
ax1.plot(sessions_JC274[10:12], accuracy_JC274[10:12], color='0.8', linewidth=linefmt, ls='--', marker='o', markersize=markerfmt) # gray line
ax1.plot(sessions_JC274[11:12], accuracy_JC274[11:12], color='k', linewidth=linefmt, marker='o', markersize=markerfmt)

##### JC283 #####
ax1.plot(sessions_JC283[0:13], accuracy_JC283[0:13], color=cscheme[2], linewidth=linefmt, marker='o', markersize=markerfmt, label='JC283')
# ax1.plot(sessions_JC283[10:12], accuracy_JC283[10:12], color='0.8', linewidth=linefmt, ls='--', marker='o', markersize=markerfmt) # gray line
# ax1.plot(sessions_JC283[11:12], accuracy_JC283[11:12], color='k', linewidth=linefmt, marker='o', markersize=markerfmt)

# ##### Formatting #####
# ax1.set_title("Performance first day of third paired association", fontsize=26,y=1.03)
# ax1.tick_params(labelsize=15)
# ax1.set_xlabel("Training day", fontsize=15)
# ax1.set_ylabel("Accuracy", fontsize=15)
# # ax1.set_xlim(0.5,8.5) # just to align the two subplot x-axes
# ax1.xaxis.set_major_locator(mtick.MultipleLocator(1))
# ax1.set_ylim(-5,100)
# ax1.yaxis.set_major_formatter(mtick.FormatStrFormatter('%.0f%%'))
# ax1.yaxis.grid()
# # ax1.margins(x=0.05)

##### Formatting large #####
ax1.set_title("Performance first day of third paired association", fontsize=50,y=1.03)
ax1.tick_params(labelsize=30)
ax1.set_xlabel("Training day", fontsize=30)
ax1.set_ylabel("Accuracy", fontsize=30)
# ax1.set_xlim(0.5,8.5) # just to align the two subplot x-axes
ax1.xaxis.set_major_locator(mtick.MultipleLocator(1))
ax1.set_xlim(0.5,14.5)
ax1.set_ylim(-5,100)
ax1.yaxis.set_major_formatter(mtick.FormatStrFormatter('%.0f%%'))
ax1.yaxis.grid()
# ax1.margins(x=0.05)

# large legend #
ax1.legend(loc=4, fontsize=30, framealpha=1)

plt.show()
timestamp = datetime.datetime.today().strftime("%Y-%m-%d-%H%M%S")
# plt.savefig("Performance 3 pairs day one "+timestamp+".png")
# plt.savefig("Performance 3 pairs day one "+timestamp+".svg")

# %%
##### Plot accuracy and arm choice before and after third paired association introduced #####
fig = plt.figure(figsize=(22,11))
plt.tight_layout()

##### Colorscheme: empty, 2-choice, 3-choice, empty #####
# cscheme = ['#264653','#2a9d8f','0.9','#7a5195','#ffa600'] # Data Color Picker 1
# cscheme = ['#003f5c', '#58508d', '#bc5090', '#ff6361','#ffa600'] # Data Color Picker 2
# cscheme = ["#264653","#2a9d8f", "#e9c46a","#b7410e"] # Coolors, modified
# cscheme = ['#1b9e77','#d95f02','0.9','#7570b3','#e7298a'] # Colorbrewer

##### Plot accuracy #####
ax1 = fig.add_subplot(111)

##### Line plot format #####
# ### Default ###
# linefmt = 2
# markerfmt = 5
### large ###
linefmt = 4 
markerfmt = 10

##### JC240 #####
ax1.plot(sessions_JC240[0:8], accuracy_JC240[0:8], color=cscheme[0], linewidth=linefmt, marker='o', markersize=markerfmt) # 2 flavors
# ax1.plot(sessions_JC240[7:16], accuracy_JC240[7:16], color=cscheme[2], linewidth=linefmt, marker='o', markersize=markerfmt) # 3 flavors with connecting line
ax1.plot(sessions_JC240[7:9], accuracy_JC240[7:9], color='0.8', linewidth=linefmt, ls='--', marker='o', markersize=markerfmt) # gray line
ax1.plot(sessions_JC240[8:16], accuracy_JC240[8:16], color=cscheme[3], linewidth=linefmt, marker='o', markersize=markerfmt) # 3 flavors without line

# ##### JC241 #####
# ax1.plot(sessions_JC241[0:13], accuracy_JC241[0:13], color=cscheme[2], linewidth=linefmt, marker='o', markersize=markerfmt) # 2 flavors
# # ax1.plot(sessions_JC241[12:16], accuracy_JC241[12:16], color=cscheme[2], linewidth=linefmt, marker='o', markersize=markerfmt) # 3 flavors with connecting line
# ax1.plot(sessions_JC241[12:14], accuracy_JC241[12:14], color='0.8', linewidth=linefmt, ls='--', marker='o', markersize=markerfmt) # gray line
# ax1.plot(sessions_JC241[13:16], accuracy_JC241[13:16], color=cscheme[3], linewidth=linefmt, marker='o', markersize=markerfmt) # 3 flavors without line

# ##### JC258 #####
# ax1.plot(sessions_JC258[0:10], accuracy_JC258[0:10], color=cscheme[1], linewidth=linefmt, marker='o', markersize=markerfmt) # 2 flavors
# ax1.plot(sessions_JC258[9:11], accuracy_JC258[9:11], color='0.8', linewidth=linefmt, ls='--', marker='o', markersize=markerfmt) # gray line
# ax1.plot(sessions_JC258[10:14], accuracy_JC258[10:14], color=cscheme[3], linewidth=linefmt, marker='o', markersize=markerfmt) # 3 flavors without line

# ##### JC274 #####
# ax1.plot(sessions_JC274[0:11], accuracy_JC274[0:11], color=cscheme[3], linewidth=linefmt, marker='o', markersize=markerfmt)
# ax1.plot(sessions_JC274[10:12], accuracy_JC274[10:12], color='0.8', linewidth=linefmt, ls='--', marker='o', markersize=markerfmt) # gray line
# ax1.plot(sessions_JC274[11:12], accuracy_JC274[11:12], color=cscheme[3], linewidth=linefmt, marker='o', markersize=markerfmt)

# ##### Formatting #####
# ax1.set_title("Performance for three paired associations", fontsize=26,y=1.03)
# ax1.tick_params(labelsize=15)
# ax1.set_xlabel("Training day", fontsize=15)
# ax1.set_ylabel("Accuracy", fontsize=15)
# # ax1.set_xlim(0.5,8.5) # just to align the two subplot x-axes
# ax1.xaxis.set_major_locator(mtick.MultipleLocator(1))
# ax1.set_ylim(-5,100)
# ax1.yaxis.set_major_formatter(mtick.FormatStrFormatter('%.0f%%'))
# ax1.yaxis.grid()
# # ax1.margins(x=0.05)

##### Formatting large #####
# ax1.set_title("Performance for three paired associations", fontsize=50,y=1.03)
ax1.set_title("JC240: learning 2, then 3 paired associations", fontsize=50,y=1.03)
ax1.tick_params(labelsize=30)
ax1.set_xlabel("Training day", fontsize=30)
ax1.set_ylabel("Accuracy", fontsize=30)
# ax1.set_xlim(0.5,8.5) # just to align the two subplot x-axes
ax1.xaxis.set_major_locator(mtick.MultipleLocator(1))
ax1.set_ylim(-5,100)
ax1.yaxis.set_major_formatter(mtick.FormatStrFormatter('%.0f%%'))
ax1.yaxis.grid()
ax1.axhline(y=80, c='black', ls='--', linewidth=3) # color formerly #ae2012
# ax1.margins(x=0.05)

##### Legend #####
# twoChoice = mpatches.Patch(color=cscheme[0], label = '2-choic')
# threeChoice = mpatches.Patch(color=cscheme[2], label = '3-choice')
# ax1.legend(handles=[twoChoice, threeChoice], loc=4, fontsize=13, fancybox=True, shadow=1, borderpad=0.5)

plt.show()
timestamp = datetime.datetime.today().strftime("%Y-%m-%d-%H%M%S")
# plt.savefig("Performance JC240 3 pairs "+timestamp+".png")
# plt.savefig("Performance 3 pairs "+timestamp+".svg")

# %%
# Compute statistics
accuracy_mean = np.mean([accuracy_JC240[0:8], accuracy_JC241[0:8]], axis=0)
accuracy_sem = stats.sem([accuracy_JC240[0:8], accuracy_JC241[0:8]], axis=0)

arm_choice_mean = np.mean([arm_choice_JC240[0:8], arm_choice_JC241[0:8]], axis=0)
arm_choice_sem = stats.sem([arm_choice_JC240[0:8], arm_choice_JC241[0:8]], axis=0)

# %%
# Plot arm choice
fig = plt.figure(figsize=(30,20))
cscheme = ["#593510", "#fcbe15", "#d2c28f", "maroon"] # chocolate, cereal, sunflower, other

##### JC240 #####
ax1 = fig.add_subplot(321)
ax1.bar(sessions_JC240, arm_choice_JC240[:,0], color=cscheme[0])
ax1.bar(sessions_JC240, arm_choice_JC240[:,1], color=cscheme[1], bottom=arm_choice_JC240[:,0])
ax1.bar(sessions_JC240, arm_choice_JC240[:,2], color=cscheme[2], bottom=arm_choice_JC240[:,0]+arm_choice_JC240[:,1])
ax1.bar(sessions_JC240, arm_choice_JC240[:,3], color=cscheme[3], bottom=arm_choice_JC240[:,0]+arm_choice_JC240[:,1]+arm_choice_JC240[:,2])

ax1.axvline(x=8.5, color='k') # start of schema learning
ax1.text(8.55, 1.1, "third flavor introduced", fontsize=12)

##### JC240 formatting #####
ax1.set_title("JC240 arm selection over time", fontsize=22)
ax1.tick_params(labelsize=15)
# ax1.set_xlabel("Training day", fontsize=15)
ax1.set_ylabel("Proportion of arm chosen", fontsize=15)
ax1.set_xlim(0.5,16.5)
ax1.set_ylim(0,1.4)
ax1.xaxis.set_major_locator(mtick.MultipleLocator(1))
ax1.yaxis.set_ticks(np.arange(0,1.4,0.2))
ax1.margins(y=0.2) # margins to make room for the legend
# Legend
chocolate_arm = mpatches.Patch(color=cscheme[0], label = 'Chocolate-rewarded arm')
honey_arm = mpatches.Patch(color=cscheme[1], label = 'Honey loop-rewarded arm')
sunflower_arm = mpatches.Patch(color=cscheme[2], label = 'Sunflower-rewarded arm')
other_arms = mpatches.Patch(color=cscheme[3], label = 'Unrewarded arms')
# ax1.legend(handles=[chocolate_arm, honey_arm, sunflower_arm, other_arms], loc=2, fontsize=11, fancybox=True, shadow=1, borderpad=0.5)


##### JC241 #####
ax2 = fig.add_subplot(322)
ax2.bar(sessions_JC241, arm_choice_JC241[:,0], color=cscheme[0])
ax2.bar(sessions_JC241, arm_choice_JC241[:,1], color=cscheme[1], bottom=arm_choice_JC241[:,0])
ax2.bar(sessions_JC241, arm_choice_JC241[:,2], color=cscheme[2], bottom=arm_choice_JC241[:,0]+arm_choice_JC241[:,1])
ax2.bar(sessions_JC241, arm_choice_JC241[:,3], color=cscheme[3], bottom=arm_choice_JC241[:,0]+arm_choice_JC241[:,1]+arm_choice_JC241[:,2])
ax2.axvline(x=13.5, color='k') # start of schema learning
ax2.text(13.55, 1.1, "third flavor introduced", fontsize=12)

##### JC241 formatting #####
ax2.set_title("JC241 arm selection over time", fontsize=22)
ax2.tick_params(labelsize=15)
# ax2.set_xlabel("Training day", fontsize=15)
ax2.set_ylabel("Proportion of arm chosen", fontsize=15)
ax2.set_xlim(0.5,16.5)
ax2.set_ylim(0,1.4)
ax2.xaxis.set_major_locator(mtick.MultipleLocator(1))
ax2.yaxis.set_ticks(np.arange(0,1.4,0.2))
ax2.margins(y=0.2) # margins to make room for the legend
# Legend
# ax2.legend(handles=[chocolate_arm, honey_arm, sunflower_arm, other_arms], loc=2, fontsize=11, fancybox=True, shadow=1, borderpad=0.5)

##### JC258 #####
ax3 = fig.add_subplot(323)
ax3.bar(sessions_JC258, arm_choice_JC258[:,0], color=cscheme[0])
ax3.bar(sessions_JC258, arm_choice_JC258[:,1], color=cscheme[1], bottom=arm_choice_JC258[:,0])
ax3.bar(sessions_JC258, arm_choice_JC258[:,2], color=cscheme[2], bottom=arm_choice_JC258[:,0]+arm_choice_JC258[:,1])
ax3.bar(sessions_JC258, arm_choice_JC258[:,3], color=cscheme[3], bottom=arm_choice_JC258[:,0]+arm_choice_JC258[:,1]+arm_choice_JC258[:,2])
ax3.axvline(x=10.5, color='k') # start of schema learning
ax3.text(10.55, 1.1, "third flavor introduced", fontsize=12)

##### JC258 formatting #####
ax3.set_title("JC258 arm selection over time", fontsize=22)
ax3.tick_params(labelsize=15)
# ax3.set_xlabel("Training day", fontsize=15)
ax3.set_ylabel("Proportion of arm chosen", fontsize=15)
ax3.set_xlim(0.5,16.5)
ax3.set_ylim(0,1.4)
ax3.xaxis.set_major_locator(mtick.MultipleLocator(1))
ax3.yaxis.set_ticks(np.arange(0,1.4,0.2))
ax3.margins(y=0.2) # margins to make room for the legend
# Legend
# ax3.legend(handles=[chocolate_arm, honey_arm, sunflower_arm, other_arms], loc=2, fontsize=11, fancybox=True, shadow=1, borderpad=0.5)

##### JC267 #####
ax4 = fig.add_subplot(324)
ax4.bar(sessions_JC267, arm_choice_JC267[:,0], color=cscheme[0])
ax4.bar(sessions_JC267, arm_choice_JC267[:,1], color=cscheme[1], bottom=arm_choice_JC267[:,0])
ax4.bar(sessions_JC267, arm_choice_JC267[:,2], color=cscheme[2], bottom=arm_choice_JC267[:,0]+arm_choice_JC267[:,1])
ax4.bar(sessions_JC267, arm_choice_JC267[:,3], color=cscheme[3], bottom=arm_choice_JC267[:,0]+arm_choice_JC267[:,1]+arm_choice_JC267[:,2])

##### JC267 formatting #####
ax4.set_title("JC267 arm selection over time", fontsize=22)
ax4.tick_params(labelsize=15)
ax4.set_xlabel("Training day", fontsize=15)
ax4.set_ylabel("Proportion of arm chosen", fontsize=15)
ax4.set_xlim(0.5,16.5)
ax4.set_ylim(0,1.4)
ax4.xaxis.set_major_locator(mtick.MultipleLocator(1))
ax4.yaxis.set_ticks(np.arange(0,1.4,0.2))
ax4.margins(y=0.2) # margins to make room for the legend
# Legend
# ax4.legend(handles=[chocolate_arm, honey_arm, sunflower_arm, other_arms], loc=7, fontsize=26, fancybox=True, shadow=1, borderpad=0.5)

##### JC274 #####
ax5 = fig.add_subplot(325)
ax5.bar(sessions_JC274, arm_choice_JC274[:,0], color=cscheme[0])
ax5.bar(sessions_JC274, arm_choice_JC274[:,1], color=cscheme[1], bottom=arm_choice_JC274[:,0])
ax5.bar(sessions_JC274, arm_choice_JC274[:,2], color=cscheme[2], bottom=arm_choice_JC274[:,0]+arm_choice_JC274[:,1])
ax5.bar(sessions_JC274, arm_choice_JC274[:,3], color=cscheme[3], bottom=arm_choice_JC274[:,0]+arm_choice_JC274[:,1]+arm_choice_JC274[:,2])
ax5.axvline(x=11.5, color='k') # start of schema learning
ax5.text(11.55, 1.1, "third flavor introduced", fontsize=12)

##### JC274 formatting #####
ax5.set_title("JC274 arm selection over time", fontsize=22)
ax5.tick_params(labelsize=15)
ax5.set_xlabel("Training day", fontsize=15)
ax5.set_ylabel("Proportion of arm chosen", fontsize=15)
ax5.set_xlim(0.5,16.5)
ax5.set_ylim(0,1.4)
ax5.xaxis.set_major_locator(mtick.MultipleLocator(1))
ax5.yaxis.set_ticks(np.arange(0,1.4,0.2))
ax5.margins(y=0.2) # margins to make room for the legend
# Legend
# ax5.legend(handles=[chocolate_arm, honey_arm, sunflower_arm, other_arms], loc=2, fontsize=11, fancybox=True, shadow=1, borderpad=0.5)

##### JC283 #####
ax6 = fig.add_subplot(326)
ax6.bar(sessions_JC283, arm_choice_JC283[:,0], color=cscheme[0])
ax6.bar(sessions_JC283, arm_choice_JC283[:,1], color=cscheme[2], bottom=arm_choice_JC283[:,0])
ax6.bar(sessions_JC283, arm_choice_JC283[:,2], color=cscheme[1], bottom=arm_choice_JC283[:,0]+arm_choice_JC283[:,1])
ax6.bar(sessions_JC283, arm_choice_JC283[:,3], color=cscheme[3], bottom=arm_choice_JC283[:,0]+arm_choice_JC283[:,1]+arm_choice_JC283[:,2])

##### JC283 formatting #####
ax6.set_title("JC283 arm selection over time", fontsize=22)
ax6.tick_params(labelsize=15)
ax6.set_xlabel("Training day", fontsize=15)
ax6.set_ylabel("Proportion of arm chosen", fontsize=15)
ax6.set_xlim(0.5,16.5)
ax6.set_ylim(0,1.4)
ax6.xaxis.set_major_locator(mtick.MultipleLocator(1))
ax6.yaxis.set_ticks(np.arange(0,1.4,0.2))
ax6.margins(y=0.2) # margins to make room for the legend

# # Add legend in the place of subplot 6
# ax6 = fig.add_subplot(326)
# ax6.axis('off') # hide axis
# ax6.legend(handles=[chocolate_arm, honey_arm, sunflower_arm, other_arms], loc=8, fontsize=26, fancybox=True, shadow=1, borderpad=0.5)

plt.show()
# plt.savefig("Arm selection over time "+timestamp+".png")
# plt.savefig("Arm selection over time "+timestamp+".svg")

# %%
##### Calculate performance by flavor #####
def get_flavor_accuracy(JCxxx, third_flavor_introduced): # hard coded variable that tells me on which session the third flavor gets introduced
                                                            # for JC240 it's 9
    data_JCxxx = str(JCxxx) + "_data" # concatenate strings for variable name
    data_JCxxx = globals()[data_JCxxx] # convert string to variable
    bysession_JCxxx = data_JCxxx.groupby("Session_ID") # filter by session ID and create a groupby object
    sessions = bysession_JCxxx["Session_ID"]  # list sessions
    
    byflavor_JCxxx = data_JCxxx.groupby("Flavor") # filter by flavor this time; create another groupby object
#     flavors = byflavor_JCxxx["Flavor"].unique() # list unique flavors
    flavors = ['C', 'H', 'S'] # hard coding for now :(
    flavor_accuracy = np.zeros((len(sessions), len(flavors))) # predefine a 16x3 array that will plot accuracy for 16 sessions and 3 flavors
    
    byboth_JCxxx = data_JCxxx.groupby(["Session_ID", "Flavor"]) # filter by both session and flavor; create a combined groupby object
    
#     # generate output of the groupby object
#     for group_key, group_value in byboth_JCxxx:
#         print(group_key, group_value)
#         group = byboth_JCxxx.get_group(group_key)
#         print(group)
        
    for session in range(1, len(sessions)+1):
        for flavor in range(len(flavors)-1): # only works for C and H for now
            correct_trials = byboth_JCxxx.get_group((session, flavors[flavor]))["CorrectBool"].sum() 
            total_trials = byboth_JCxxx.get_group((session, flavors[flavor]))["CorrectBool"].count()
            acc = correct_trials / total_trials
            flavor_accuracy[session-1][flavor] = round(acc, 2)*100
            round(bysession_JCxxx.get_group(session)["CorrectBool"].sum() / bysession_JCxxx.get_group(session).count()[0]*100, 0)
        # hard code third flavor
        if session > third_flavor_introduced-1:
            correct_trials = byboth_JCxxx.get_group((session, flavors[2]))["CorrectBool"].sum()
            total_trials = byboth_JCxxx.get_group((session, flavors[flavor]))["CorrectBool"].count()
            acc = correct_trials / total_trials
            flavor_accuracy[session-1][2] = round(acc, 2)*100
    return flavor_accuracy



###########################################################################3
##### Calculate performance by flavor for JC283 #####
def get_flavor_accuracy_JC283(JCxxx, third_flavor_introduced): # hard coded variable that tells me on which session the third flavor gets introduced
                                                            # for JC240 it's 9
    data_JCxxx = str(JCxxx) + "_data" # concatenate strings for variable name
    data_JCxxx = globals()[data_JCxxx] # convert string to variable
    bysession_JCxxx = data_JCxxx.groupby("Session_ID") # filter by session ID and create a groupby object
    sessions = bysession_JCxxx["Session_ID"]  # list sessions
    
    byflavor_JCxxx = data_JCxxx.groupby("Flavor") # filter by flavor this time; create another groupby object
#     flavors = byflavor_JCxxx["Flavor"].unique() # list unique flavors
    flavors = ['C', 'S', 'H'] # hard coding for now :(
    flavor_accuracy = np.zeros((len(sessions), len(flavors))) # predefine a 16x3 array that will plot accuracy for 16 sessions and 3 flavors
    
    byboth_JCxxx = data_JCxxx.groupby(["Session_ID", "Flavor"]) # filter by both session and flavor; create a combined groupby object
    
#     # generate output of the groupby object
#     for group_key, group_value in byboth_JCxxx:
#         print(group_key, group_value)
#         group = byboth_JCxxx.get_group(group_key)
#         print(group)

    for session in range(1, len(sessions)+1):
        for flavor in range(len(flavors)-1): # only works for C and S for now
            correct_trials = byboth_JCxxx.get_group((session, flavors[flavor]))["CorrectBool"].sum() 
            total_trials = byboth_JCxxx.get_group((session, flavors[flavor]))["CorrectBool"].count()
            acc = correct_trials / total_trials
            flavor_accuracy[session-1][flavor] = round(acc, 2)*100
            round(bysession_JCxxx.get_group(session)["CorrectBool"].sum() / bysession_JCxxx.get_group(session).count()[0]*100, 0)
#         # hard code third flavor
#         if session > third_flavor_introduced-1:
#             correct_trials = byboth_JCxxx.get_group((session, flavors[2]))["CorrectBool"].sum()
#             total_trials = byboth_JCxxx.get_group((session, flavors[flavor]))["CorrectBool"].count()
#             acc = correct_trials / total_trials
#             flavor_accuracy[session-1][2] = round(acc, 2)*100
    return flavor_accuracy

third_flv_sess_JC240 = 9
flavor_accuracy_JC240 = get_flavor_accuracy("JC240", third_flv_sess_JC240)

third_flv_sess_JC241 = 14
flavor_accuracy_JC241 = get_flavor_accuracy("JC241", third_flv_sess_JC241)

third_flv_sess_JC258 = 11
flavor_accuracy_JC258 = get_flavor_accuracy("JC258", third_flv_sess_JC258)

third_flv_sess_JC267 = len(sessions_JC267)+1 # third flavor never introduced
flavor_accuracy_JC267 = get_flavor_accuracy("JC267", third_flv_sess_JC267)

third_flv_sess_JC274 = 12
flavor_accuracy_JC274 = get_flavor_accuracy("JC274", third_flv_sess_JC274)

third_flv_sess_JC283 = 9
flavor_accuracy_JC283 = get_flavor_accuracy_JC283("JC283", third_flv_sess_JC283)

# %%
##### Plot accuracy by flavor #####
fig = plt.figure(figsize=(22,11))
plt.tight_layout()
ax = fig.add_subplot(111)

##### Line plot format #####
# ### Default ###
# linefmt = 2
# markerfmt = 5
### large ###
linefmt = 4 
markerfmt = 10

##### JC240 #####
ax.plot(sessions_JC240, flavor_accuracy_JC240[:, 0], color='#964B00', linewidth=linefmt, marker='o', markersize=markerfmt) # chocolate
ax.plot(sessions_JC240, flavor_accuracy_JC240[:, 1], color='#FFBF00', linewidth=linefmt, marker='o', markersize=markerfmt) # honey
# ax.plot(sessions_JC240[third_flv_sess_JC240-1:-1], flavor_accuracy_JC240[third_flv_sess_JC240-1:-1, 2], color='#CFB997', linewidth=linefmt, marker='o', markersize=markerfmt) # sunflower
#             # for some reason the last day isn't getting plotted
ax.axvline(x=third_flv_sess_JC240-0.5, color='k') # start of schema learning

# ##### Formatting #####
# ax1.set_title("Performance for three paired associations", fontsize=26,y=1.03)
# ax1.tick_params(labelsize=15)
# ax1.set_xlabel("Training day", fontsize=15)
# ax1.set_ylabel("Accuracy", fontsize=15)
# # ax1.set_xlim(0.5,8.5) # just to align the two subplot x-axes
# ax1.xaxis.set_major_locator(mtick.MultipleLocator(1))
# ax1.set_ylim(-5,100)
# ax1.yaxis.set_major_formatter(mtick.FormatStrFormatter('%.0f%%'))
# ax1.yaxis.grid()
# # ax1.margins(x=0.05)

##### Formatting large #####
ax.set_title("Performance by flavor for JC240", fontsize=50,y=1.03)
ax.tick_params(labelsize=30)
ax.set_xlabel("Training day", fontsize=30)
ax.set_ylabel("Accuracy", fontsize=30)
# ax.xaxis.set_major_locator(mtick.MultipleLocator(1))
ax.set_ylim(-5,105)
ax.yaxis.set_major_formatter(mtick.FormatStrFormatter('%.0f%%'))
ax.yaxis.grid()
# ax.margins(x=0.05)

##### Legend #####
# twoChoice = mpatches.Patch(color=cscheme[0], label = '2-choice')
# threeChoice = mpatches.Patch(color=cscheme[2], label = '3-choice')
# ax1.legend(handles=[twoChoice, threeChoice], loc=4, fontsize=13, fancybox=True, shadow=1, borderpad=0.5)

plt.show()
timestamp = datetime.datetime.today().strftime("%Y-%m-%d-%H%M%S")
# plt.savefig("Performance by flavor JC240 "+timestamp+".png")
# plt.savefig("Performance by flavor JC240 "+timestamp+".svg")

# %%
##### Plot accuracy by flavor #####
fig = plt.figure(figsize=(22,11))
plt.tight_layout()
ax = fig.add_subplot(111)

##### Line plot format #####
# ### Default ###
# linefmt = 2
# markerfmt = 5
### large ###
linefmt = 4 
markerfmt = 10

##### JC241 #####
ax.plot(sessions_JC241, flavor_accuracy_JC241[:, 0], color='#964B00', linewidth=linefmt, marker='o', markersize=markerfmt) # chocolate
ax.plot(sessions_JC241, flavor_accuracy_JC241[:, 1], color='#FFBF00', linewidth=linefmt, marker='o', markersize=markerfmt) # honey
# ax.plot(sessions_JC241[third_flv_sess_JC241-1:-1], flavor_accuracy_JC241[third_flv_sess_JC241-1:-1, 2], color='#CFB997', linewidth=linefmt, marker='o', markersize=markerfmt) # sunflower
#             # for some reason the last day isn't getting plotted
ax.axvline(x=third_flv_sess_JC241-0.5, color='k') # start of schema learning

# ##### Formatting #####
# ax1.set_title("Performance for three paired associations", fontsize=26,y=1.03)
# ax1.tick_params(labelsize=15)
# ax1.set_xlabel("Training day", fontsize=15)
# ax1.set_ylabel("Accuracy", fontsize=15)
# # ax1.set_xlim(0.5,8.5) # just to align the two subplot x-axes
# ax1.xaxis.set_major_locator(mtick.MultipleLocator(1))
# ax1.set_ylim(-5,100)
# ax1.yaxis.set_major_formatter(mtick.FormatStrFormatter('%.0f%%'))
# ax1.yaxis.grid()
# # ax1.margins(x=0.05)

##### Formatting large #####
ax.set_title("Performance by flavor for JC241", fontsize=50,y=1.03)
ax.tick_params(labelsize=30)
ax.set_xlabel("Training day", fontsize=30)
ax.set_ylabel("Accuracy", fontsize=30)
# ax.xaxis.set_major_locator(mtick.MultipleLocator(1))
ax.set_ylim(-5,105)
ax.yaxis.set_major_formatter(mtick.FormatStrFormatter('%.0f%%'))
ax.yaxis.grid()
# ax.margins(x=0.05)

##### Legend #####
# twoChoice = mpatches.Patch(color=cscheme[0], label = '2-choice')
# threeChoice = mpatches.Patch(color=cscheme[2], label = '3-choice')
# ax1.legend(handles=[twoChoice, threeChoice], loc=4, fontsize=13, fancybox=True, shadow=1, borderpad=0.5)

plt.show()
timestamp = datetime.datetime.today().strftime("%Y-%m-%d-%H%M%S")
# plt.savefig("Performance by flavor JC241 "+timestamp+".png")
# plt.savefig("Performance by flavor JC241 "+timestamp+".svg")

# %%
##### Plot accuracy by flavor #####
fig = plt.figure(figsize=(22,11))
plt.tight_layout()
ax = fig.add_subplot(111)

##### Line plot format #####
# ### Default ###
# linefmt = 2
# markerfmt = 5
### large ###
linefmt = 4 
markerfmt = 10

##### JC258 #####
ax.plot(sessions_JC258, flavor_accuracy_JC258[:, 0], color='#964B00', linewidth=linefmt, marker='o', markersize=markerfmt) # chocolate
ax.plot(sessions_JC258, flavor_accuracy_JC258[:, 1], color='#FFBF00', linewidth=linefmt, marker='o', markersize=markerfmt) # honey
# ax.plot(sessions_JC258[third_flv_sess_JC258:-1], flavor_accuracy_JC258[third_flv_sess_JC258:-1, 2], color='#CFB997', linewidth=linefmt, marker='o', markersize=markerfmt) # sunflower
#             # for some reason the last day isn't getting plotted
ax.axvline(x=third_flv_sess_JC258-0.5, color='k') # start of schema learning

# ##### Formatting #####
# ax1.set_title("Performance for three paired associations", fontsize=26,y=1.03)
# ax1.tick_params(labelsize=15)
# ax1.set_xlabel("Training day", fontsize=15)
# ax1.set_ylabel("Accuracy", fontsize=15)
# # ax1.set_xlim(0.5,8.5) # just to align the two subplot x-axes
# ax1.xaxis.set_major_locator(mtick.MultipleLocator(1))
# ax1.set_ylim(-5,100)
# ax1.yaxis.set_major_formatter(mtick.FormatStrFormatter('%.0f%%'))
# ax1.yaxis.grid()
# # ax1.margins(x=0.05)

##### Formatting large #####
ax.set_title("Performance by flavor for JC258", fontsize=50,y=1.03)
ax.tick_params(labelsize=30)
ax.set_xlabel("Training day", fontsize=30)
ax.set_ylabel("Accuracy", fontsize=30)
# ax.xaxis.set_major_locator(mtick.MultipleLocator(1))
ax.set_ylim(-5,105)
ax.yaxis.set_major_formatter(mtick.FormatStrFormatter('%.0f%%'))
ax.yaxis.grid()
# ax.margins(x=0.05)

##### Legend #####
# twoChoice = mpatches.Patch(color=cscheme[0], label = '2-choice')
# threeChoice = mpatches.Patch(color=cscheme[2], label = '3-choice')
# ax1.legend(handles=[twoChoice, threeChoice], loc=4, fontsize=13, fancybox=True, shadow=1, borderpad=0.5)

plt.show()
timestamp = datetime.datetime.today().strftime("%Y-%m-%d-%H%M%S")
# plt.savefig("Performance by flavor JC258 "+timestamp+".png")
# plt.savefig("Performance by flavor JC258 "+timestamp+".svg")

# %%
##### Plot accuracy by flavor #####
fig = plt.figure(figsize=(22,11))
plt.tight_layout()
ax = fig.add_subplot(111)

##### Line plot format #####
# ### Default ###
# linefmt = 2
# markerfmt = 5
### large ###
linefmt = 4 
markerfmt = 10

##### JC267 #####
ax.plot(sessions_JC267, flavor_accuracy_JC267[:, 0], color='#964B00', linewidth=linefmt, marker='o', markersize=markerfmt) # chocolate
ax.plot(sessions_JC267, flavor_accuracy_JC267[:, 1], color='#FFBF00', linewidth=linefmt, marker='o', markersize=markerfmt) # honey

# ##### Formatting #####
# ax1.set_title("Performance for three paired associations", fontsize=26,y=1.03)
# ax1.tick_params(labelsize=15)
# ax1.set_xlabel("Training day", fontsize=15)
# ax1.set_ylabel("Accuracy", fontsize=15)
# # ax1.set_xlim(0.5,8.5) # just to align the two subplot x-axes
# ax1.xaxis.set_major_locator(mtick.MultipleLocator(1))
# ax1.set_ylim(-5,100)
# ax1.yaxis.set_major_formatter(mtick.FormatStrFormatter('%.0f%%'))
# ax1.yaxis.grid()
# # ax1.margins(x=0.05)

##### Formatting large #####
ax.set_title("Performance by flavor for JC267", fontsize=50,y=1.03)
ax.tick_params(labelsize=30)
ax.set_xlabel("Training day", fontsize=30)
ax.set_ylabel("Accuracy", fontsize=30)
ax.set_xlim(0.5,10)
# ax.xaxis.set_major_locator(mtick.MultipleLocator(1))
ax.set_ylim(-5,105)
ax.yaxis.set_major_formatter(mtick.FormatStrFormatter('%.0f%%'))
ax.yaxis.grid()
# ax.margins(x=0.05)

##### Legend #####
# twoChoice = mpatches.Patch(color=cscheme[0], label = '2-choice')
# threeChoice = mpatches.Patch(color=cscheme[2], label = '3-choice')
# ax1.legend(handles=[twoChoice, threeChoice], loc=4, fontsize=13, fancybox=True, shadow=1, borderpad=0.5)

plt.show()
timestamp = datetime.datetime.today().strftime("%Y-%m-%d-%H%M%S")
# plt.savefig("Performance by flavor JC258 "+timestamp+".png")
# plt.savefig("Performance by flavor JC258 "+timestamp+".svg")

# %%
##### Plot accuracy by flavor #####
fig = plt.figure(figsize=(22,11))
plt.tight_layout()
ax = fig.add_subplot(111)

##### Line plot format #####
# ### Default ###
# linefmt = 2
# markerfmt = 5
### large ###
linefmt = 4 
markerfmt = 10

##### JC274 #####
ax.plot(sessions_JC274, flavor_accuracy_JC274[:, 0], color='#964B00', linewidth=linefmt, marker='o', markersize=markerfmt) # chocolate
ax.plot(sessions_JC274, flavor_accuracy_JC274[:, 1], color='#FFBF00', linewidth=linefmt, marker='o', markersize=markerfmt) # honey
# ax.plot(sessions_JC274[third_flv_sess_JC274:-1], flavor_accuracy_JC274[third_flv_sess_JC258:-1, 2], color='#CFB997', linewidth=linefmt, marker='o', markersize=markerfmt) # sunflower
#             # for some reason the last day isn't getting plotted
ax.axvline(x=third_flv_sess_JC274-0.5, color='k') # start of schema learning

# ##### Formatting #####
# ax1.set_title("Performance for three paired associations", fontsize=26,y=1.03)
# ax1.tick_params(labelsize=15)
# ax1.set_xlabel("Training day", fontsize=15)
# ax1.set_ylabel("Accuracy", fontsize=15)
# # ax1.set_xlim(0.5,8.5) # just to align the two subplot x-axes
# ax1.xaxis.set_major_locator(mtick.MultipleLocator(1))
# ax1.set_ylim(-5,100)
# ax1.yaxis.set_major_formatter(mtick.FormatStrFormatter('%.0f%%'))
# ax1.yaxis.grid()
# # ax1.margins(x=0.05)

##### Formatting large #####
ax.set_title("Performance by food for JC274", fontsize=50,y=1.03)
ax.tick_params(labelsize=30)
ax.set_xlabel("Training day", fontsize=30)
ax.set_ylabel("Accuracy", fontsize=30)
# ax.xaxis.set_major_locator(mtick.MultipleLocator(1))
ax.set_ylim(-5,105)
ax.yaxis.set_major_formatter(mtick.FormatStrFormatter('%.0f%%'))
ax.yaxis.grid()
# ax.margins(x=0.05)

##### Legend #####
# twoChoice = mpatches.Patch(color=cscheme[0], label = '2-choice')
# threeChoice = mpatches.Patch(color=cscheme[2], label = '3-choice')
# ax1.legend(handles=[twoChoice, threeChoice], loc=4, fontsize=13, fancybox=True, shadow=1, borderpad=0.5)

plt.show()
timestamp = datetime.datetime.today().strftime("%Y-%m-%d-%H%M%S")
# plt.savefig("Performance by food JC274 "+timestamp+".png")
# plt.savefig("Performance by food JC274 "+timestamp+".svg")
# plt.savefig("Performance by food JC274 "+timestamp+".jpg")

# %%
##### Plot accuracy by flavor #####
fig = plt.figure(figsize=(22,11))
plt.tight_layout()
ax = fig.add_subplot(111)

##### Line plot format #####
# ### Default ###
# linefmt = 2
# markerfmt = 5
### large ###
linefmt = 4 
markerfmt = 10

##### JC283 #####
ax.plot(sessions_JC283, flavor_accuracy_JC283[:, 0], color='#964B00', linewidth=linefmt, marker='o', markersize=markerfmt) # chocolate
ax.plot(sessions_JC283, flavor_accuracy_JC283[:, 1], color=cscheme[2], linewidth=linefmt, marker='o', markersize=markerfmt) # honey
# ax.plot(sessions_JC283[third_flv_sess_JC283:-1], flavor_accuracy_JC283[third_flv_sess_JC258:-1, 2], color='#CFB997', linewidth=linefmt, marker='o', markersize=markerfmt) # sunflower
#             # for some reason the last day isn't getting plotted
#ax.axvline(x=third_flv_sess_JC283-0.5, color='k') # start of schema learning



# ##### Formatting #####
# ax1.set_title("Performance for three paired associations", fontsize=26,y=1.03)
# ax1.tick_params(labelsize=15)
# ax1.set_xlabel("Training day", fontsize=15)
# ax1.set_ylabel("Accuracy", fontsize=15)
# # ax1.set_xlim(0.5,8.5) # just to align the two subplot x-axes
# ax1.xaxis.set_major_locator(mtick.MultipleLocator(1))
# ax1.set_ylim(-5,100)
# ax1.yaxis.set_major_formatter(mtick.FormatStrFormatter('%.0f%%'))
# ax1.yaxis.grid()
# # ax1.margins(x=0.05)

##### Formatting large #####
ax.set_title("Performance by food for JC283", fontsize=50,y=1.03)
ax.tick_params(labelsize=30)
ax.set_xlabel("Training day", fontsize=30)
ax.set_ylabel("Accuracy", fontsize=30)
# ax.xaxis.set_major_locator(mtick.MultipleLocator(1))
ax.set_ylim(-5,105)
ax.yaxis.set_major_formatter(mtick.FormatStrFormatter('%.0f%%'))
ax.yaxis.grid()
# ax.margins(x=0.05)

##### Legend #####
# twoChoice = mpatches.Patch(color=cscheme[0], label = '2-choice')
# threeChoice = mpatches.Patch(color=cscheme[2], label = '3-choice')
# ax1.legend(handles=[twoChoice, threeChoice], loc=4, fontsize=13, fancybox=True, shadow=1, borderpad=0.5)

plt.show()
timestamp = datetime.datetime.today().strftime("%Y-%m-%d-%H%M%S")
# plt.savefig("Performance by food JC283 "+timestamp+".png")
# plt.savefig("Performance by food JC283 "+timestamp+".svg")
# plt.savefig("Performance by food JC283 "+timestamp+".jpg")

# %%
##### Plot accuracy by flavor #####
fig = plt.figure(figsize=(22,16))
# plt.tight_layout()
# fig.suptitle("Performance by flavor", y=0.98, fontsize=30)

### large ###
linefmt = 4 
markerfmt = 10

# Colorscheme
chocolate = '#964B00'
honey = '#FFBF00'

##### JC258 #####
ax1 = fig.add_subplot(211)
ax1.plot(sessions_JC258, flavor_accuracy_JC258[:, 0], color=chocolate, linewidth=linefmt, marker='o', markersize=markerfmt) # chocolate
ax1.plot(sessions_JC258, flavor_accuracy_JC258[:, 1], color=honey, linewidth=linefmt, marker='o', markersize=markerfmt) # honey
ax1.axvline(x=third_flv_sess_JC258-0.5, color='k', linewidth=linefmt) # start of schema learning
ax1.text(third_flv_sess_JC258-0.4, 1, "third flavor introduced", fontsize=20)

##### Formatting large #####
ax1.set_title("Performance by flavor for JC258 and JC274", fontsize=50, y=1.12)
ax1.tick_params(labelsize=30)
# ax1.set_xlabel("Training day", fontsize=30)
ax1.set_ylabel("Accuracy", fontsize=30)
# ax.xaxis.set_major_locator(mtick.MultipleLocator(1))
ax1.set_ylim(-5,105)
ax1.yaxis.set_major_formatter(mtick.FormatStrFormatter('%.0f%%'))
ax1.yaxis.grid()
# ax.margins(x=0.05)

##### JC274 #####
ax2 = fig.add_subplot(212)
ax2.plot(sessions_JC274, flavor_accuracy_JC274[:, 0], color=chocolate, linewidth=linefmt, marker='o', markersize=markerfmt) # chocolate
ax2.plot(sessions_JC274, flavor_accuracy_JC274[:, 1], color=honey, linewidth=linefmt, marker='o', markersize=markerfmt) # honey
ax2.axvline(x=third_flv_sess_JC274-0.5, color='k', linewidth=linefmt) # start of schema learning


##### Formatting large #####
# ax2.set_title("JC274", fontsize=23,y=1.03)
ax2.tick_params(labelsize=30)
ax2.set_xlabel("Training day", fontsize=30)
ax2.set_ylabel("Accuracy", fontsize=30)
# ax.xaxis.set_major_locator(mtick.MultipleLocator(1))
ax2.set_ylim(-5,105)
ax2.yaxis.set_major_formatter(mtick.FormatStrFormatter('%.0f%%'))
ax2.yaxis.grid()
# ax.margins(x=0.05)

# ##### Formatting #####
# ax1.set_title("Performance for two paired associations", fontsize=26,y=1.03)
# ax1.tick_params(labelsize=15)
# ax1.set_xlabel("Training day", fontsize=15)
# ax1.set_ylabel("Accuracy", fontsize=15)
# # ax1.set_xlim(0.5,8.5) # just to align the two subplot x-axes
# ax1.xaxis.set_major_locator(mtick.MultipleLocator(1))
# ax1.set_ylim(-5,100)
# ax1.yaxis.set_major_formatter(mtick.FormatStrFormatter('%.0f%%'))
# ax1.yaxis.grid()
# # ax1.margins(x=0.05)

##### Legend #####
chocolate_legend = mpatches.Patch(color=chocolate, label = 'chocolate')
honey_legend = mpatches.Patch(color=honey, label = 'honey')
ax2.legend(handles=[chocolate_legend, honey_legend], loc=4, fontsize=30, fancybox=True, shadow=1, borderpad=0.5)

plt.show()
timestamp = datetime.datetime.today().strftime("%Y-%m-%d-%H%M%S")
# plt.savefig("Performance by flavor JC258 and JC274 "+timestamp+".png")
# plt.savefig("Performance by flavor JC258 and JC274 "+timestamp+".svg")

# %%
##### Plot accuracy by flavor #####
fig = plt.figure(figsize=(22,16))
# plt.tight_layout()
# fig.suptitle("Performance by flavor", y=0.98, fontsize=30)

### large ###
linefmt = 4 
markerfmt = 10

# Colorscheme
chocolate = '#964B00'
honey = '#FFBF00'
sunflower = "#d2c28f"

##### JC274 #####
ax1 = fig.add_subplot(211)
ax1.plot(sessions_JC274, flavor_accuracy_JC274[:, 0], color=chocolate, linewidth=linefmt, marker='o', markersize=markerfmt) # chocolate
ax1.plot(sessions_JC274, flavor_accuracy_JC274[:, 1], color=honey, linewidth=linefmt, marker='o', markersize=markerfmt) # honey
ax1.axvline(x=third_flv_sess_JC274-0.5, color='k', linewidth=linefmt) # start of schema learning


##### Formatting large #####
# ax2.set_title("JC274", fontsize=23,y=1.03)
ax1.set_title("Performance by flavor for JC274 and JC283", fontsize=50, y=1.12)
ax1.tick_params(labelsize=30)
ax1.set_xlabel("Training day", fontsize=30)
ax1.set_ylabel("Accuracy", fontsize=30)
# ax.xaxis.set_major_locator(mtick.MultipleLocator(1))
ax1.set_ylim(-5,105)
ax1.yaxis.set_major_formatter(mtick.FormatStrFormatter('%.0f%%'))
ax1.yaxis.grid()
# ax.margins(x=0.05)

##### JC283 #####
ax2 = fig.add_subplot(212)
ax2.plot(sessions_JC283, flavor_accuracy_JC283[:, 0], color=chocolate, linewidth=linefmt, marker='o', markersize=markerfmt) # chocolate
ax2.plot(sessions_JC283, flavor_accuracy_JC283[:, 1], color=sunflower, linewidth=linefmt, marker='o', markersize=markerfmt) # sunflower
# ax2.axvline(x=third_flv_sess_JC283-0.5, color='k', linewidth=linefmt) # start of schema learning
# ax2.text(third_flv_sess_JC283-0.4, 1, "third flavor introduced", fontsize=20)

##### Formatting large #####
ax2.tick_params(labelsize=30)
# ax2.set_xlabel("Training day", fontsize=30)
ax2.set_ylabel("Accuracy", fontsize=30)
# ax.xaxis.set_major_locator(mtick.MultipleLocator(1))
ax2.set_ylim(-5,105)
ax2.yaxis.set_major_formatter(mtick.FormatStrFormatter('%.0f%%'))
ax2.yaxis.grid()
# ax.margins(x=0.05)

# ##### Formatting #####
# ax1.set_title("Performance for two paired associations", fontsize=26,y=1.03)
# ax1.tick_params(labelsize=15)
# ax1.set_xlabel("Training day", fontsize=15)
# ax1.set_ylabel("Accuracy", fontsize=15)
# # ax1.set_xlim(0.5,8.5) # just to align the two subplot x-axes
# ax1.xaxis.set_major_locator(mtick.MultipleLocator(1))
# ax1.set_ylim(-5,100)
# ax1.yaxis.set_major_formatter(mtick.FormatStrFormatter('%.0f%%'))
# ax1.yaxis.grid()
# # ax1.margins(x=0.05)

##### Legend #####
chocolate_legend = mpatches.Patch(color=chocolate, label = 'chocolate')
honey_legend = mpatches.Patch(color=honey, label = 'honey')
sunflower_legend = mpatches.Patch(color=sunflower, label = 'sunflower')
ax2.legend(handles=[chocolate_legend, honey_legend, sunflower_legend], loc=4, fontsize=30, fancybox=True, shadow=1, borderpad=0.5)

plt.show()
timestamp = datetime.datetime.today().strftime("%Y-%m-%d-%H%M%S")
# plt.savefig("Performance by flavor JC274 and JC283 "+timestamp+".png")
# plt.savefig("Performance by flavor JC274 and JC283 "+timestamp+".jpg")
# plt.savefig("Performance by flavor JC274 and JC283 "+timestamp+".svg")

# %%
##### Plot accuracy by flavor = all animals #####
fig = plt.figure(figsize=(37,27))
plt.tight_layout()
# fig.suptitle("Performance by flavor", y=0.98, fontsize=30)

### large ###
linefmt = 4
markerfmt = 10

# Colorscheme
cscheme = ["#593510", "#fcbe15", "#d2c28f"] # chocolate, cereal, sunflower
chocolate = '#593510'
honey = '#fcbe15'

##### JC240 #####
ax1 = fig.add_subplot(321)
ax1.plot(sessions_JC240, flavor_accuracy_JC240[:, 0], color=chocolate, linewidth=linefmt, marker='o', markersize=markerfmt) # chocolate
ax1.plot(sessions_JC240, flavor_accuracy_JC240[:, 1], color=honey, linewidth=linefmt, marker='o', markersize=markerfmt) # honey
# ax.plot(sessions_JC240[third_flv_sess_JC240-1:-1], flavor_accuracy_JC240[third_flv_sess_JC240-1:-1, 2], color='#CFB997', linewidth=linefmt, marker='o', markersize=markerfmt) # sunflower
#             # for some reason the last day isn't getting plotted
ax1.axvline(x=third_flv_sess_JC240-0.5, color='k') # start of schema learning

##### Formatting large #####
ax1.set_title("Performance by flavor for JC240", fontsize=35,y=1.03)
ax1.tick_params(labelsize=30)
# ax1.set_xlabel("Training day", fontsize=30)
ax1.set_ylabel("Accuracy", fontsize=30)
ax1.xaxis.set_major_locator(mtick.MultipleLocator(2))
ax1.set_xlim(0.5,17)
ax1.set_ylim(-5,105)
ax1.yaxis.set_major_formatter(mtick.FormatStrFormatter('%.0f%%'))
ax1.yaxis.grid()
# ax.margins(x=0.05)

##### JC241 #####
ax2 = fig.add_subplot(322)
ax2.plot(sessions_JC241, flavor_accuracy_JC241[:, 0], color=chocolate, linewidth=linefmt, marker='o', markersize=markerfmt) # chocolate
ax2.plot(sessions_JC241, flavor_accuracy_JC241[:, 1], color=honey, linewidth=linefmt, marker='o', markersize=markerfmt) # honey
# ax2.plot(sessions_JC241[third_flv_sess_JC241-1:-1], flavor_accuracy_JC241[third_flv_sess_JC241-1:-1, 2], color='#CFB997', linewidth=linefmt, marker='o', markersize=markerfmt) # sunflower
#             # for some reason the last day isn't getting plotted
ax2.axvline(x=third_flv_sess_JC241-0.5, color='k') # start of schema learning

##### Formatting large #####
ax2.set_title("JC241", fontsize=35,y=1.03)
ax2.tick_params(labelsize=30)
# ax2.set_xlabel("Training day", fontsize=30)
ax2.set_ylabel("Accuracy", fontsize=30)
ax2.xaxis.set_major_locator(mtick.MultipleLocator(2))
ax2.set_xlim(0.5,17)
ax2.set_ylim(-5,105)
ax2.yaxis.set_major_formatter(mtick.FormatStrFormatter('%.0f%%'))
ax2.yaxis.grid()
# ax2.margins(x=0.05)


##### JC258 #####
ax3 = fig.add_subplot(323)
ax3.plot(sessions_JC258, flavor_accuracy_JC258[:, 0], color=chocolate, linewidth=linefmt, marker='o', markersize=markerfmt) # chocolate
ax3.plot(sessions_JC258, flavor_accuracy_JC258[:, 1], color=honey, linewidth=linefmt, marker='o', markersize=markerfmt) # honey
ax3.axvline(x=third_flv_sess_JC258-0.5, color='k', linewidth=linefmt) # start of schema learning
ax3.text(third_flv_sess_JC258-0.4, 1, "third flavor introduced", fontsize=20)

##### Formatting large #####
ax3.set_title("JC258", fontsize=35, y=1.03)
ax3.tick_params(labelsize=30)
# ax3.set_xlabel("Training day", fontsize=30)
ax3.set_ylabel("Accuracy", fontsize=30)
ax3.xaxis.set_major_locator(mtick.MultipleLocator(2))
ax3.set_xlim(0.5,17)
ax3.set_ylim(-5,105)
ax3.yaxis.set_major_formatter(mtick.FormatStrFormatter('%.0f%%'))
ax3.yaxis.grid()
# ax3.margins(x=0.05)

##### JC267 #####
ax4 = fig.add_subplot(324)
ax4.plot(sessions_JC267, flavor_accuracy_JC267[:, 0], color=chocolate, linewidth=linefmt, marker='o', markersize=markerfmt) # chocolate
ax4.plot(sessions_JC267, flavor_accuracy_JC267[:, 1], color=honey, linewidth=linefmt, marker='o', markersize=markerfmt) # honey

##### Formatting large #####
ax4.set_title("JC267", fontsize=35,y=1.03)
ax4.tick_params(labelsize=30)
ax4.set_xlabel("Training day", fontsize=30)
ax4.set_ylabel("Accuracy", fontsize=30)
ax4.xaxis.set_major_locator(mtick.MultipleLocator(2))
ax4.set_xlim(0.5,17)
ax4.set_ylim(-5,105)
ax4.yaxis.set_major_formatter(mtick.FormatStrFormatter('%.0f%%'))
ax4.yaxis.grid()
# ax4.margins(x=0.05)


##### JC274 #####
ax5 = fig.add_subplot(325)
ax5.plot(sessions_JC274, flavor_accuracy_JC274[:, 0], color=chocolate, linewidth=linefmt, marker='o', markersize=markerfmt) # chocolate
ax5.plot(sessions_JC274, flavor_accuracy_JC274[:, 1], color=honey, linewidth=linefmt, marker='o', markersize=markerfmt) # honey
ax5.axvline(x=third_flv_sess_JC274-0.5, color='k', linewidth=linefmt) # start of schema learning

##### Formatting large #####
ax5.set_title("JC274", fontsize=35,y=1.03)
ax5.tick_params(labelsize=35)
ax5.set_xlabel("Training day", fontsize=30)
ax5.set_ylabel("Accuracy", fontsize=30)
# ax.xaxis.set_major_locator(mtick.MultipleLocator(1))
ax5.set_ylim(-5,105)
ax5.yaxis.set_major_formatter(mtick.FormatStrFormatter('%.0f%%'))
ax5.yaxis.grid()
# ax5.margins(x=0.05)

# ##### Formatting #####
# ax1.set_title("Performance for two paired associations", fontsize=26,y=1.03)
# ax1.tick_params(labelsize=15)
# ax1.set_xlabel("Training day", fontsize=15)
# ax1.set_ylabel("Accuracy", fontsize=15)
# # ax1.set_xlim(0.5,8.5) # just to align the two subplot x-axes
# ax1.xaxis.set_major_locator(mtick.MultipleLocator(1))
# ax1.set_ylim(-5,100)
# ax1.yaxis.set_major_formatter(mtick.FormatStrFormatter('%.0f%%'))
# ax1.yaxis.grid()
# # ax1.margins(x=0.05)

# Add legend in the place of subplot 6
ax6 = fig.add_subplot(326)
ax6.axis('off') # hide axis

##### Legend #####
chocolate_legend = mpatches.Patch(color=chocolate, label = 'chocolate')
honey_legend = mpatches.Patch(color=honey, label = 'honey')
ax6.legend(handles=[chocolate_legend, honey_legend], loc=8, fontsize=30, fancybox=True, shadow=1, borderpad=0.5)

plt.show()
timestamp = datetime.datetime.today().strftime("%Y-%m-%d-%H%M%S")
# plt.savefig("Performance by flavor JC258 and JC274 "+timestamp+".png")
# plt.savefig("Performance by flavor JC258 and JC274 "+timestamp+".svg")
